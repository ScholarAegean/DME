# %%
import pandas as pd
data=pd.read_csv('Dataset4_Extended.csv')
del data['Unnamed: 0']
data
# Out:
#                                      Company  Total       Since       Until  \
# 0                                 3sun Group   10.0  2014-02-01  2019-04-01
# 1                                     Abacus    4.0  2013-08-01  2019-04-01
# 2                               Accsys Group   12.0  2017-03-01  2019-04-01
# 3                                       Acro    7.0  2015-11-01  2017-09-01
# 4                               ACS Clothing   25.0  2014-01-01  2019-04-01
# 5                              AdEPT Telecom    9.0  2016-09-01  2019-04-01
# 6                                 ADEPT4 plc    5.0  2016-06-01  2019-04-01
# 7                                    Adestra    5.0  2016-01-01  2019-04-01
# 8                                   AimBrain    4.0  2017-06-01  2019-04-01
# 9                               Anstey Horne    6.0  2016-03-01  2019-04-01
# 10                        Apex Housing Group    6.0  2018-06-01  2019-04-01
# ...

# %%
data['Since']=pd.DatetimeIndex(data['Since']).year  
data['Type']='COMPANY'
data
# Out:
#                                      Company  Total  Since       Until  \
# 0                                 3sun Group   10.0   2014  2019-04-01
# 1                                     Abacus    4.0   2013  2019-04-01
# 2                               Accsys Group   12.0   2017  2019-04-01
# 3                                       Acro    7.0   2015  2017-09-01
# 4                               ACS Clothing   25.0   2014  2019-04-01
# 5                              AdEPT Telecom    9.0   2016  2019-04-01
# 6                                 ADEPT4 plc    5.0   2016  2019-04-01
# 7                                    Adestra    5.0   2016  2019-04-01
# 8                                   AimBrain    4.0   2017  2019-04-01
# 9                               Anstey Horne    6.0   2016  2019-04-01
# 10                        Apex Housing Group    6.0   2018  2019-04-01
# 11                                      APSU    7.0   2014  2016-11-01
# ...

# %%
data.to_csv('DATA4.csv')

# %%
data=pd.read_csv('dataset2_filtered.csv')
del data['Unnamed: 0']
data

# %%
data['year']=pd.DatetimeIndex(data['StartDate']).year  
data1=data

# %%
del data1['StartDate']
del data1['EndDate']
del data1['FundingOrgName']
data2=data1

# %% [markdown]
# Complete Datasets

# %%
data2

# %%
data_sector.to_csv("Region.csv")

# %%
dataf=pd.read_csv('data2_countTYPE.csv')
dataf
df = dataf.rename(columns={'LeadROName': 'counts'})

# %%
df.to_csv('Data2_counsTYPE')

# %%
data_count_type=dataf.groupby('ProjectCategory').count()

# %%
data_count_type.to_csv('data2_countTYPE.csv')

# %%
df=pd.read_csv('Data2_countsTYPE.csv')
del df['Unnamed: 0']

# %%
df.to_csv('data2_countTYPE.csv')

# %%
df.to_csv('data2_countTYPE.csv')
