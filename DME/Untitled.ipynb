# %%
import pandas as pd
data=pd.read_csv('data1_2csv.csv')
data = data.drop(data[data.Year > 2016].index)
data
# Out:
#             Value  Year ProviderType    Purpose
# 0         10875.0  2012      COMPANY  EDUCATION
# 1       1981982.0  2012      COMPANY  EDUCATION
# 2        198971.0  2012      COMPANY  EDUCATION
# 3       7197409.0  2012      COMPANY  EDUCATION
# 4          8064.0  2012      COMPANY  EDUCATION
# 5         28409.0  2012      COLLEGE  EDUCATION
# 6        239224.0  2012      COLLEGE  EDUCATION
# 7       3155112.0  2012      COLLEGE  EDUCATION
# 8         64233.0  2012      COLLEGE  EDUCATION
# 9        474780.0  2012      COLLEGE  EDUCATION
# 10       647267.0  2012      COMPANY  EDUCATION
# 11      2386299.0  2012      COMPANY  EDUCATION
# 12       144202.0  2012      COMPANY  EDUCATION
# 13      2128731.0  2012      COMPANY  EDUCATION
# 14        11013.0  2012      COMPANY  EDUCATION
# 15        19191.0  2012      COMPANY  EDUCATION
# 16       118020.0  2012      COMPANY  EDUCATION
# 17       485553.0  2012      COMPANY  EDUCATION
# 18         7343.0  2012      COMPANY  EDUCATION
# ...

# %%
import pandas as pd
data=pd.read_csv('data1_2csv.csv')
data = data.drop(data[data.Year > 2016].index)
data
# Out:
#             Value  Year ProviderType    Purpose
# 0         10875.0  2012      COMPANY  EDUCATION
# 1       1981982.0  2012      COMPANY  EDUCATION
# 2        198971.0  2012      COMPANY  EDUCATION
# 3       7197409.0  2012      COMPANY  EDUCATION
# 4          8064.0  2012      COMPANY  EDUCATION
# 5         28409.0  2012      COLLEGE  EDUCATION
# 6        239224.0  2012      COLLEGE  EDUCATION
# 7       3155112.0  2012      COLLEGE  EDUCATION
# 8         64233.0  2012      COLLEGE  EDUCATION
# 9        474780.0  2012      COLLEGE  EDUCATION
# 10       647267.0  2012      COMPANY  EDUCATION
# 11      2386299.0  2012      COMPANY  EDUCATION
# 12       144202.0  2012      COMPANY  EDUCATION
# 13      2128731.0  2012      COMPANY  EDUCATION
# 14        11013.0  2012      COMPANY  EDUCATION
# 15        19191.0  2012      COMPANY  EDUCATION
# 16       118020.0  2012      COMPANY  EDUCATION
# 17       485553.0  2012      COMPANY  EDUCATION
# 18         7343.0  2012      COMPANY  EDUCATION
# ...

# %%
df['ProviderType']=df['ProviderType'].map(lambda x : "UNIVERSITY" if 'UNIVERSITY' in x else x)
df

# %%
df['ProviderType']=df['ProviderType'].map(lambda x : x if x=='UNIVERSITY' or x=='COLLEGE' in x else 'COMPANY')
df

# %%
data2=data1.dropna(axis = 0)

# %%
data.to_csv('Dataset1to2.csv')

# %%
import pandas as pd
data=pd.read_csv('DATA1.csv')
data
# Out:
#                    Funding_Line      Value  Year ProviderType
# 0         16-18 Apprenticeships    10875.0  2012      COMPANY
# 1        Adult Education Budget  1981982.0  2012      COMPANY
# 2         16-18 Apprenticeships   198971.0  2012      COMPANY
# 3        Adult Education Budget  7197409.0  2012      COMPANY
# 4         16-18 Apprenticeships     8064.0  2012      COMPANY
# 5            Community Learning    28409.0  2012      COLLEGE
# 6         16-18 Apprenticeships   239224.0  2012      COLLEGE
# 7        Adult Education Budget  3155112.0  2012      COLLEGE
# 8        Adult Education Budget    64233.0  2012      COLLEGE
# 9         16-18 Apprenticeships   474780.0  2012      COLLEGE
# 10        16-18 Apprenticeships   647267.0  2012      COMPANY
# 11       Adult Education Budget  2386299.0  2012      COMPANY
# 12        16-18 Apprenticeships   144202.0  2012      COMPANY
# 13       Adult Education Budget  2128731.0  2012      COMPANY
# ...

# %%
data['Purpose']='EDUCATION'
# Out:
#                    Funding_Line      Value  Year ProviderType    Purpose
# 0         16-18 Apprenticeships    10875.0  2012      COMPANY  EDUCATION
# 1        Adult Education Budget  1981982.0  2012      COMPANY  EDUCATION
# 2         16-18 Apprenticeships   198971.0  2012      COMPANY  EDUCATION
# 3        Adult Education Budget  7197409.0  2012      COMPANY  EDUCATION
# 4         16-18 Apprenticeships     8064.0  2012      COMPANY  EDUCATION
# 5            Community Learning    28409.0  2012      COLLEGE  EDUCATION
# 6         16-18 Apprenticeships   239224.0  2012      COLLEGE  EDUCATION
# 7        Adult Education Budget  3155112.0  2012      COLLEGE  EDUCATION
# 8        Adult Education Budget    64233.0  2012      COLLEGE  EDUCATION
# 9         16-18 Apprenticeships   474780.0  2012      COLLEGE  EDUCATION
# 10        16-18 Apprenticeships   647267.0  2012      COMPANY  EDUCATION
# 11       Adult Education Budget  2386299.0  2012      COMPANY  EDUCATION
# ...

# %%
del data['Funding_Line']
data
# Out:
#            Value  Year ProviderType    Purpose
# 0        10875.0  2012      COMPANY  EDUCATION
# 1      1981982.0  2012      COMPANY  EDUCATION
# 2       198971.0  2012      COMPANY  EDUCATION
# 3      7197409.0  2012      COMPANY  EDUCATION
# 4         8064.0  2012      COMPANY  EDUCATION
# 5        28409.0  2012      COLLEGE  EDUCATION
# 6       239224.0  2012      COLLEGE  EDUCATION
# 7      3155112.0  2012      COLLEGE  EDUCATION
# 8        64233.0  2012      COLLEGE  EDUCATION
# 9       474780.0  2012      COLLEGE  EDUCATION
# 10      647267.0  2012      COMPANY  EDUCATION
# 11     2386299.0  2012      COMPANY  EDUCATION
# 12      144202.0  2012      COMPANY  EDUCATION
# 13     2128731.0  2012      COMPANY  EDUCATION
# 14       11013.0  2012      COMPANY  EDUCATION
# 15       19191.0  2012      COMPANY  EDUCATION
# 16      118020.0  2012      COMPANY  EDUCATION
# 17      485553.0  2012      COMPANY  EDUCATION
# 18        7343.0  2012      COMPANY  EDUCATION
# ...

# %%
data.to_csv('DATA1.add.csv')

# %%
pd.read_csv{''}
